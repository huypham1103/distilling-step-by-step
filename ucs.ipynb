# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv('answered_questions_rationales.csv')

# %%
df.columns
# Out:
# Index(['question', 'choices', 'final_answer', 'if_else', 'contrastive',
#        'neutral', 'consensus', 'causal', 'comparative', 'historical'],
#       dtype='object')

# %%
class UCS:
    def __init__(self) -> None:
        pass
    
    def token_probabilities(self, generations):
        """
        Compute the token probabilities for each word in the generations.
        """
        total_tokens = sum(len(gen.split()) for gen in generations)
        token_freq = {}
        for gen in generations:
            for token in gen.split():
                token_freq[token] = token_freq.get(token, 0) + 1
        return {token: freq / total_tokens for token, freq in token_freq.items()}
    
    def compute_UCS(self, generation, token_probs):
        """
    Compute the unigram consistency score (UCS) for a generation.
    """
        return sum(token_probs.get(token, 0) for token in generation.split())
    
    def compute_WUCS(self, generation, token_probs):
        """
        Compute the weighted unigram consistency score (WUCS) for a generation.
        """
        return sum(token_probs.get(token, 0) ** 2 for token in generation.split())
    
    def compute_Consensus_WUCS(self, generation, token_probs):
        """
        Compute the Consensus-WUCS for a generation.
        """
        WUCS = self.compute_WUCS(generation, token_probs)
        mean_log_prob = sum(
            math.log(token_probs.get(token, 1)) for token in generation.split()
        ) / len(generation.split())
        return WUCS * math.exp(mean_log_prob)

# %%
ucs = UCS()

# %%
# Example usage
generations = ["The sky is blue.", "The sky looks blue.", "Blue is the color of the sky."]
token_probs = ucs.token_probabilities(generations)

generation_to_evaluate = "The sky is blue."
ucs_score = ucs.compute_UCS(generation_to_evaluate, token_probs)
print(f"UCS for '{generation_to_evaluate}' is: {ucs_score:.4f}")
# Out:
# UCS for 'The sky is blue.' is: 0.5333

# %%
# Example usage
generations = ["The sky is blue.", "The sky looks blue.", "Blue is the color of the sky."]
token_probs = ucs.token_probabilities(generations)

generation_to_evaluate = "The sky is blue."
wucs_score = ucs.compute_WUCS(generation_to_evaluate, token_probs)
print(f"WUCS for '{generation_to_evaluate}' is: {wucs_score:.4f}")
# Out:
# WUCS for 'The sky is blue.' is: 0.0711

# %%
# Example usage
generations = ["The sky is blue.", "The sky looks blue.", "Blue is the color of the sky."]
token_probs = ucs.token_probabilities(generations)

generation_to_evaluate = "The sky is blue."
consensus_wucs_score = ucs.compute_Consensus_WUCS(generation_to_evaluate, token_probs)
print(f"Consensus-WUCS for '{generation_to_evaluate}' is: {consensus_wucs_score:.4f}")
# Out:
# Consensus-WUCS for 'The sky is blue.' is: 0.0095

# %%
lines = df[['contrastive', 'neutral', 'consensus', 'causal', 'comparative', 'historical']].values
lines.shape
# Out:
# (10962, 6)

# %%
def get_highest_rationales(lines, type='UCS'):
    # Example usage
    res = []
    for line in lines:
        line_res = {}
        generations = line
        token_probs = ucs.token_probabilities(generations)

        for j in range(len(line)):
            generation_to_evaluate = line[j]
            if type=='UCS':
                consensus_wucs_score = ucs.compute_UCS(generation_to_evaluate, token_probs)
            elif type=='WUCS':
                consensus_wucs_score = ucs.compute_WUCS(generation_to_evaluate, token_probs)
            elif type=='Consensus-WUCS':
                consensus_wucs_score = ucs.compute_Consensus_WUCS(generation_to_evaluate, token_probs)
            
            line_res[line[j]] = consensus_wucs_score
        
        # get the rationale with the highest UCS score
        max_key = max(line_res, key=line_res.get)
        res.append(max_key)

    return res

# %%
ucs_score = get_highest_rationales(lines, type='UCS')
wucs_score = get_highest_rationales(lines, type='WUCS')
consensus_wucs_score = get_highest_rationales(lines, type='Consensus-WUCS')

# %%
df['ucs_score'] = ucs_score
df['wucs_score'] = wucs_score
df['consensus_wucs_score'] = consensus_wucs_score

# %%
df.to_csv('answered_questions_rationales_UCS_WUCS_CWUCS.csv', index=False)

# %%
df
# Out:
#                                                 question  \
# 0      "There are 10 apples on an apple tree.  Three ...
# 1      A John is a bum.  Much like the stereotype, he...
# 2      A bad person places little value on being hone...
# 3         A bald eagle flies over St. Paul, where is it?
# 4      A battleship is a powerful vessel.  If you nee...
# ...                                                  ...
# 10957  what does someone have that causes them commit...
# 10958    what is printed with ink and distributed daily?
# 10959   when communicating with my boss what should i do
# 10960          where is a good place to obtain new soap?
# 10961                             where is seaweed from?
#
#                                                  choices       final_answer  \
# 0      ['park', 'coloring book', 'garden center', 'ma...               park
# 1      ['bus depot', 'beach', 'train station', 'bridg...             bridge
# 2      ['excellent', 'upright', 'premium', 'competent...          excellent
# 3      ['texas', 'thermal', 'minnesota', 'canada', 'p...              texas
# 4      ['yatch', 'corvette', 'aircraft carrier', 'des...              yatch
# ...                                                  ...                ...
# 10957  ['problems', 'distress', 'fear', 'go to jail',...           problems
# 10958  ['fountain pen', 'squid', 'newspaper', 'book',...       fountain pen
# 10959  ['misunderstandings', 'transfer of information...  misunderstandings
# 10960  ['supermarket', 'washing', 'cabinet', 'own hom...        supermarket
# 10961    ['beach', 'sea', 'ocean', 'water', 'sea plant']              beach
#
#                                                  if_else  \
# 0      Let's examine each option meticulously to make...
# 1      Let's examine each option meticulously to make...
# 2      Let's examine each option meticulously to make...
# 3      Let's examine each option meticulously to make...
# 4      Let's examine each option meticulously to make...
# ...                                                  ...
# 10957  Let's examine each option meticulously to make...
# 10958  Let's examine each option meticulously to make...
# 10959  Let's examine each option meticulously to make...
# 10960  Let's examine each option meticulously to make...
# 10961  Let's examine each option meticulously to make...
#
#                                              contrastive  \
# 0      The choice of 'park' provides a meaningful con...
# 1      The choice of 'bridge' provides a meaningful c...
# 2      The choice of 'excellent' provides a meaningfu...
# 3      The choice of 'texas' provides a meaningful co...
# 4      The choice of 'yatch' provides a meaningful co...
# ...                                                  ...
# 10957  The choice of 'problems' provides a meaningful...
# 10958  The choice of 'fountain pen' provides a meanin...
# 10959  The choice of 'misunderstandings' provides a m...
# 10960  The choice of 'supermarket' provides a meaning...
# 10961  The choice of 'beach' provides a meaningful co...
#
#                                                  neutral  \
# 0      The option of 'park' manages to encapsulate th...
# 1      The option of 'bridge' manages to encapsulate ...
# 2      The option of 'excellent' manages to encapsula...
# 3      The option of 'texas' manages to encapsulate t...
# 4      The option of 'yatch' manages to encapsulate t...
# ...                                                  ...
# 10957  The option of 'problems' manages to encapsulat...
# 10958  The option of 'fountain pen' manages to encaps...
# 10959  The option of 'misunderstandings' manages to e...
# 10960  The option of 'supermarket' manages to encapsu...
# 10961  The option of 'beach' manages to encapsulate t...
#
#                                                consensus  \
# 0      In a general sense, 'park' would likely gain t...
# 1      In a general sense, 'bridge' would likely gain...
# 2      In a general sense, 'excellent' would likely g...
# 3      In a general sense, 'texas' would likely gain ...
# 4      In a general sense, 'yatch' would likely gain ...
# ...                                                  ...
# 10957  In a general sense, 'problems' would likely ga...
# 10958  In a general sense, 'fountain pen' would likel...
# 10959  In a general sense, 'misunderstandings' would ...
# 10960  In a general sense, 'supermarket' would likely...
# 10961  In a general sense, 'beach' would likely gain ...
#
#                                                   causal  \
# 0      Examining the question and the possible answer...
# 1      Examining the question and the possible answer...
# 2      Examining the question and the possible answer...
# 3      Examining the question and the possible answer...
# 4      Examining the question and the possible answer...
# ...                                                  ...
# 10957  Examining the question and the possible answer...
# 10958  Examining the question and the possible answer...
# 10959  Examining the question and the possible answer...
# 10960  Examining the question and the possible answer...
# 10961  Examining the question and the possible answer...
#
#                                              comparative  \
# 0      When lined up against other available choices ...
# 1      When lined up against other available choices ...
# 2      When lined up against other available choices ...
# 3      When lined up against other available choices ...
# 4      When lined up against other available choices ...
# ...                                                  ...
# 10957  When lined up against other available choices ...
# 10958  When lined up against other available choices ...
# 10959  When lined up against other available choices ...
# 10960  When lined up against other available choices ...
# 10961  When lined up against other available choices ...
#
#                                               historical  \
# 0      Drawing from past instances, previous quizzes,...
# 1      Drawing from past instances, previous quizzes,...
# 2      Drawing from past instances, previous quizzes,...
# 3      Drawing from past instances, previous quizzes,...
# 4      Drawing from past instances, previous quizzes,...
# ...                                                  ...
# 10957  Drawing from past instances, previous quizzes,...
# 10958  Drawing from past instances, previous quizzes,...
# 10959  Drawing from past instances, previous quizzes,...
# 10960  Drawing from past instances, previous quizzes,...
# 10961  Drawing from past instances, previous quizzes,...
#
#                                                ucs_score  \
# 0      Drawing from past instances, previous quizzes,...
# 1      Drawing from past instances, previous quizzes,...
# 2      Drawing from past instances, previous quizzes,...
# 3      Drawing from past instances, previous quizzes,...
# 4      Drawing from past instances, previous quizzes,...
# ...                                                  ...
# 10957  Drawing from past instances, previous quizzes,...
# 10958  The choice of 'fountain pen' provides a meanin...
# 10959  Drawing from past instances, previous quizzes,...
# 10960  Drawing from past instances, previous quizzes,...
# 10961  Drawing from past instances, previous quizzes,...
#
#                                               wucs_score  \
# 0      The choice of 'park' provides a meaningful con...
# 1      The choice of 'bridge' provides a meaningful c...
# 2      The choice of 'excellent' provides a meaningfu...
# 3      The choice of 'texas' provides a meaningful co...
# 4      The choice of 'yatch' provides a meaningful co...
# ...                                                  ...
# 10957  The choice of 'problems' provides a meaningful...
# 10958  The choice of 'fountain pen' provides a meanin...
# 10959  The choice of 'misunderstandings' provides a m...
# 10960  The choice of 'supermarket' provides a meaning...
# 10961  The choice of 'beach' provides a meaningful co...
#
#                                     consensus_wucs_score
# 0      The choice of 'park' provides a meaningful con...
# 1      The choice of 'bridge' provides a meaningful c...
# 2      The choice of 'excellent' provides a meaningfu...
# 3      The choice of 'texas' provides a meaningful co...
# 4      The choice of 'yatch' provides a meaningful co...
# ...                                                  ...
# 10957  The choice of 'problems' provides a meaningful...
# 10958  The choice of 'fountain pen' provides a meanin...
# 10959  The choice of 'misunderstandings' provides a m...
# 10960  The choice of 'supermarket' provides a meaning...
# 10961  The choice of 'beach' provides a meaningful co...
#
# [10962 rows x 13 columns]
