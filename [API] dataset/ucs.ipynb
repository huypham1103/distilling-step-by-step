# %%
import pandas as pd
import numpy as np
import math

# %%
# read file csv
if_else = pd.read_csv('if_else - full.csv', index_col=0)
contrastive = pd.read_csv('contrastive - full.csv', index_col=0)
neutral = pd.read_csv('neutral - full.csv', index_col=0)
consensus = pd.read_csv('consensus - full.csv', index_col=0)
causal = pd.read_csv('causal - full.csv', index_col=0)
comparative = pd.read_csv('comparative - full.csv', index_col=0)
historical = pd.read_csv('historical - full.csv', index_col=0)

# %%
historical
# Out:
#                                                                                               premise  \
# question
# A man with a white camp is standing on a platfo...  A man with a white camp is standing on a platf...
# Two girls wearing skirts like the flag of Great...  Two girls wearing skirts like the flag of Grea...
# Dog leaps from water while woman kneels on the ...  Dog leaps from water while woman kneels on the...
# A bald man in an orange shirt and jeans is vacu...  A bald man in an orange shirt and jeans is vac...
# A boy stands beside a railing at a go kart trac...  A boy stands beside a railing at a go kart track.
# ...                                                                                               ...
# Three women walk down a city street; one looks ...  Three women walk down a city street; one looks...
# A basketball player slam dunks the ball as his ...  A basketball player slam dunks the ball as his...
# Two kids wearing white robes are practicing mar...  Two kids wearing white robes are practicing ma...
# Three naked little boys are playing in a river ...  Three naked little boys are playing in a river...
# A female belly dancer dressed in blue and orang...  A female belly dancer dressed in blue and oran...
#
#                                                                                            hypothesis  \
# question
# A man with a white camp is standing on a platfo...             A man is hanging off of a clothesline.
# Two girls wearing skirts like the flag of Great...                       a couple want to eat a flag.
# Dog leaps from water while woman kneels on the ...            A woman and dog sit on a dock together.
# A bald man in an orange shirt and jeans is vacu...             The clothed man is cleaning the carpet
# A boy stands beside a railing at a go kart trac...                The boy is going to ride a go kart.
# ...                                                                                               ...
# Three women walk down a city street; one looks ...                          Three women chat at home.
# A basketball player slam dunks the ball as his ...  The ball player is competing in a slam dunk co...
# Two kids wearing white robes are practicing mar...              The boys are practicing martial arts.
# Three naked little boys are playing in a river ...  Three boys are playing in mud while one looks on.
# A female belly dancer dressed in blue and orang...  A female has clothes on with two males holding...
#
#                                                                                            rationales  \
# question
# A man with a white camp is standing on a platfo...  1. Premise: A man with a white camp is standin...
# Two girls wearing skirts like the flag of Great...  2. Premise: Two girls wearing skirts like the ...
# Dog leaps from water while woman kneels on the ...  3. Premise: Dog leaps from water while woman k...
# A bald man in an orange shirt and jeans is vacu...  4. Premise: A bald man in an orange shirt and ...
# A boy stands beside a railing at a go kart trac...  5. Premise: A boy stands beside a railing at a...
# ...                                                                                               ...
# Three women walk down a city street; one looks ...  8. Premise: Three women walk down a city stree...
# A basketball player slam dunks the ball as his ...  9. Premise: A basketball player slam dunks the...
# Two kids wearing white robes are practicing mar...  10. Premise: Two kids wearing white robes are ...
# Three naked little boys are playing in a river ...  Premise: Three naked little boys are playing i...
# A female belly dancer dressed in blue and orang...  Premise: A female belly dancer dressed in blue...
#
#                                                                                                 split  \
# question
# A man with a white camp is standing on a platfo...  1. premise: a man with a white camp is standin...
# Two girls wearing skirts like the flag of Great...  2. premise: two girls wearing skirts like the ...
# Dog leaps from water while woman kneels on the ...  3. premise: dog leaps from water while woman k...
# A bald man in an orange shirt and jeans is vacu...  4. premise: a bald man in an orange shirt and ...
# A boy stands beside a railing at a go kart trac...  5. premise: a boy stands beside a railing at a...
# ...                                                                                               ...
# Three women walk down a city street; one looks ...  8. premise: three women walk down a city stree...
# A basketball player slam dunks the ball as his ...  9. premise: a basketball player slam dunks the...
# Two kids wearing white robes are practicing mar...  10. premise: two kids wearing white robes are ...
# Three naked little boys are playing in a river ...  premise: three naked little boys are playing i...
# A female belly dancer dressed in blue and orang...  premise: a female belly dancer dressed in blue...
#
#                                                                                    correct_index  \
# question
# A man with a white camp is standing on a platfo...  {'contradiction': 193, 'contradictory': 411}
# Two girls wearing skirts like the flag of Great...                        {'contradiction': 120}
# Dog leaps from water while woman kneels on the ...                           {'entailment': 143}
# A bald man in an orange shirt and jeans is vacu...                           {'entailment': 179}
# A boy stands beside a railing at a go kart trac...                              {'neutral': 119}
# ...                                                                                          ...
# Three women walk down a city street; one looks ...    {'contradiction': 143, 'contradicts': 323}
# A basketball player slam dunks the ball as his ...                           {'entailment': 194}
# Two kids wearing white robes are practicing mar...                           {'entailment': 235}
# Three naked little boys are playing in a river ...    {'contradiction': 170, 'contradicts': 412}
# A female belly dancer dressed in blue and orang...                              {'neutral': 255}
#
#                                                        LLM_answer
# question
# A man with a white camp is standing on a platfo...  contradiction
# Two girls wearing skirts like the flag of Great...  contradiction
# Dog leaps from water while woman kneels on the ...     entailment
# A bald man in an orange shirt and jeans is vacu...     entailment
# A boy stands beside a railing at a go kart trac...        neutral
# ...                                                           ...
# Three women walk down a city street; one looks ...  contradiction
# A basketball player slam dunks the ball as his ...     entailment
# Two kids wearing white robes are practicing mar...     entailment
# Three naked little boys are playing in a river ...  contradiction
# A female belly dancer dressed in blue and orang...        neutral
#
# [5592 rows x 6 columns]

# %%
total_df = if_else[['premise', 'hypothesis']]

# %%
total_df['if_else'] = if_else['rationales']
total_df['contrastive'] = contrastive['rationales']
total_df['neutral'] = neutral['rationales']
total_df['consensus'] = consensus['rationales']
total_df['causal'] = causal['rationales']
total_df['comparative'] = comparative['rationales']
total_df['historical'] = historical['rationales']
# Out:
# <ipython-input-21-cc1d2f7ccc9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df['if_else'] = if_else['rationales']
# <ipython-input-21-cc1d2f7ccc9c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df['contrastive'] = contrastive['rationales']
# <ipython-input-21-cc1d2f7ccc9c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df['neutral'] = neutral['rationales']

# %%
total_df.head()
# Out:
#                                                                                               premise  \
# question
# A man with a white camp is standing on a platfo...  A man with a white camp is standing on a platf...
# Two girls wearing skirts like the flag of Great...  Two girls wearing skirts like the flag of Grea...
# Dog leaps from water while woman kneels on the ...  Dog leaps from water while woman kneels on the...
# A bald man in an orange shirt and jeans is vacu...  A bald man in an orange shirt and jeans is vac...
# A boy stands beside a railing at a go kart trac...  A boy stands beside a railing at a go kart track.
#
#                                                                                  hypothesis  \
# question
# A man with a white camp is standing on a platfo...   A man is hanging off of a clothesline.
# Two girls wearing skirts like the flag of Great...             a couple want to eat a flag.
# Dog leaps from water while woman kneels on the ...  A woman and dog sit on a dock together.
# A bald man in an orange shirt and jeans is vacu...   The clothed man is cleaning the carpet
# A boy stands beside a railing at a go kart trac...      The boy is going to ride a go kart.
#
#                                                                                               if_else  \
# question
# A man with a white camp is standing on a platfo...  1. Premise: A man with a white camp is standin...
# Two girls wearing skirts like the flag of Great...  2. Premise: Two girls wearing skirts like the ...
# Dog leaps from water while woman kneels on the ...  3. Premise: Dog leaps from water while woman k...
# A bald man in an orange shirt and jeans is vacu...  4. Premise: A bald man in an orange shirt and ...
# A boy stands beside a railing at a go kart trac...  5. Premise: A boy stands beside a railing at a...
#
#                                                                                           contrastive  \
# question
# A man with a white camp is standing on a platfo...  1. The most likely answer is "contradiction". ...
# Two girls wearing skirts like the flag of Great...  2. The most likely answer is "neutral". The pr...
# Dog leaps from water while woman kneels on the ...  3. The most likely answer is "entailment". The...
# A bald man in an orange shirt and jeans is vacu...  4. The most likely answer is "entailment". The...
# A boy stands beside a railing at a go kart trac...  5. The most likely answer is "entailment". The...
#
#                                                                                               neutral  \
# question
# A man with a white camp is standing on a platfo...  1. Premise: A man with a white camp is standin...
# Two girls wearing skirts like the flag of Great...  2. Premise: Two girls wearing skirts like the ...
# Dog leaps from water while woman kneels on the ...  3. Premise: Dog leaps from water while woman k...
# A bald man in an orange shirt and jeans is vacu...  4. Premise: A bald man in an orange shirt and ...
# A boy stands beside a railing at a go kart trac...  5. Premise: A boy stands beside a railing at a...
#
#                                                                                             consensus  \
# question
# A man with a white camp is standing on a platfo...  1. The commonly agreed-upon answer is "contrad...
# Two girls wearing skirts like the flag of Great...  2. The commonly agreed-upon answer is "neutral...
# Dog leaps from water while woman kneels on the ...  3. The commonly agreed-upon answer is "entailm...
# A bald man in an orange shirt and jeans is vacu...  4. The commonly agreed-upon answer is "entailm...
# A boy stands beside a railing at a go kart trac...  5. The commonly agreed-upon answer is "neutral...
#
#                                                                                                causal  \
# question
# A man with a white camp is standing on a platfo...  1. The correct answer is "contradiction". The ...
# Two girls wearing skirts like the flag of Great...  2. The correct answer is "neutral". The premis...
# Dog leaps from water while woman kneels on the ...  3. The correct answer is "entailment". The pre...
# A bald man in an orange shirt and jeans is vacu...  4. The correct answer is "entailment". The pre...
# A boy stands beside a railing at a go kart trac...  5. The correct answer is "entailment". The pre...
#
#                                                                                           comparative  \
# question
# A man with a white camp is standing on a platfo...  1. The most likely answer is "contradiction." ...
# Two girls wearing skirts like the flag of Great...  2. The most likely answer is "neutral." The pr...
# Dog leaps from water while woman kneels on the ...  3. The most likely answer is "entailment." The...
# A bald man in an orange shirt and jeans is vacu...  4. The most likely answer is "entailment." The...
# A boy stands beside a railing at a go kart trac...  5. The most likely answer is "neutral." The pr...
#
#                                                                                            historical
# question
# A man with a white camp is standing on a platfo...  1. Premise: A man with a white camp is standin...
# Two girls wearing skirts like the flag of Great...  2. Premise: Two girls wearing skirts like the ...
# Dog leaps from water while woman kneels on the ...  3. Premise: Dog leaps from water while woman k...
# A bald man in an orange shirt and jeans is vacu...  4. Premise: A bald man in an orange shirt and ...
# A boy stands beside a railing at a go kart trac...  5. Premise: A boy stands beside a railing at a...

# %%
class UCS:
    def __init__(self) -> None:
        pass
    
    def token_probabilities(self, generations):
        """
        Compute the token probabilities for each word in the generations.
        """
        total_tokens = sum(len(gen.split()) for gen in generations)
        token_freq = {}
        for gen in generations:
            for token in gen.split():
                token_freq[token] = token_freq.get(token, 0) + 1
        return {token: freq / total_tokens for token, freq in token_freq.items()}
    
    def compute_UCS(self, generation, token_probs):
        """
    Compute the unigram consistency score (UCS) for a generation.
    """
        return sum(token_probs.get(token, 0) for token in generation.split())
    
    def compute_WUCS(self, generation, token_probs):
        """
        Compute the weighted unigram consistency score (WUCS) for a generation.
        """
        return sum(token_probs.get(token, 0) ** 2 for token in generation.split())
    
    def compute_Consensus_WUCS(self, generation, token_probs):
        """
        Compute the Consensus-WUCS for a generation.
        """
        WUCS = self.compute_WUCS(generation, token_probs)
        mean_log_prob = sum(
            math.log(token_probs.get(token, 1)) for token in generation.split()
        ) / len(generation.split())
        return WUCS * math.exp(mean_log_prob)

# %%
ucs = UCS()

# %%
# Example usage
generations = ["The sky is blue.", "The sky looks blue.", "Blue is the color of the sky."]
token_probs = ucs.token_probabilities(generations)

generation_to_evaluate = "The sky is blue."
ucs_score = ucs.compute_UCS(generation_to_evaluate, token_probs)
print(f"UCS for '{generation_to_evaluate}' is: {ucs_score:.4f}")
# Out:
# UCS for 'The sky is blue.' is: 0.5333

# %%
# Example usage
generations = ["The sky is blue.", "The sky looks blue.", "Blue is the color of the sky."]
token_probs = ucs.token_probabilities(generations)

generation_to_evaluate = "The sky is blue."
wucs_score = ucs.compute_WUCS(generation_to_evaluate, token_probs)
print(f"WUCS for '{generation_to_evaluate}' is: {wucs_score:.4f}")
# Out:
# WUCS for 'The sky is blue.' is: 0.0711

# %%
# Example usage
generations = ["The sky is blue.", "The sky looks blue.", "Blue is the color of the sky."]
token_probs = ucs.token_probabilities(generations)

generation_to_evaluate = "The sky is blue."
consensus_wucs_score = ucs.compute_Consensus_WUCS(generation_to_evaluate, token_probs)
print(f"Consensus-WUCS for '{generation_to_evaluate}' is: {consensus_wucs_score:.4f}")
# Out:
# Consensus-WUCS for 'The sky is blue.' is: 0.0095

# %%
lines = total_df[['contrastive', 'neutral', 'consensus', 'causal', 'comparative', 'historical']].values
lines.shape
# Out:
# (5592, 6)

# %%
def get_highest_rationales(lines, type='UCS'):
    # Example usage
    res = []
    for line in lines:
        line_res = {}
        generations = line
        token_probs = ucs.token_probabilities(generations)

        for j in range(len(line)):
            generation_to_evaluate = line[j]
            if type=='UCS':
                consensus_wucs_score = ucs.compute_UCS(generation_to_evaluate, token_probs)
            elif type=='WUCS':
                consensus_wucs_score = ucs.compute_WUCS(generation_to_evaluate, token_probs)
            elif type=='Consensus-WUCS':
                consensus_wucs_score = ucs.compute_Consensus_WUCS(generation_to_evaluate, token_probs)
            
            line_res[line[j]] = consensus_wucs_score
        
        # get the rationale with the highest UCS score
        max_key = max(line_res, key=line_res.get)
        res.append(max_key)

    return res

# %%
ucs_score = get_highest_rationales(lines, type='UCS')
wucs_score = get_highest_rationales(lines, type='WUCS')
consensus_wucs_score = get_highest_rationales(lines, type='Consensus-WUCS')

# %%
total_df['ucs_score'] = ucs_score
total_df['wucs_score'] = wucs_score
total_df['consensus_wucs_score'] = consensus_wucs_score

# %%
total_df.to_csv('total.csv')
